# %% [markdown]
# <a href="https://colab.research.google.com/github/muka28/udacity_ml_refresherr/blob/master/training_models_with_scikit_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Training Models in scikit learn

# %%
import pandas as pd
import numpy as np


#Read the data
data = pd.read_csv("sample_data/data.csv")
data.head()
# Out:
#          x1        x2    y
# 0  0.336494 -0.985951  0.0
# 1 -0.011043 -0.105529  1.0
# 2  0.238160 -0.617417  1.0
# 3 -0.366783 -0.713819  1.0
# 4  1.221923 -1.039399  0.0

# %%
#Split the data into X and y
X = np.array(data[['x1', 'x2']])
y = np.array(data['y'])

# %%
#import statements for the classification algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# %%
#Logistic Regression
classifier = LogisticRegression()
classifier.fit(X, y)
# Out:
# LogisticRegression()

# %%
#Neural Network
classifier = MLPClassifier()
classifier.fit(X, y)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier()

# %%
#Decision Tree
classifier = DecisionTreeClassifier()
classifier.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
#Support Vector Machines
classifier = SVC()
classifier.fit(X, y)
# Out:
# SVC()
